# %% [markdown]
# <a href="https://colab.research.google.com/github/Raulgmg1999/DataScience/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_total_tienda1 = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()

print(f"Ingreso total Tienda 1: {ingreso_total_tienda1}")
print(f"Ingreso total Tienda 2: {ingreso_total_tienda2}")
print(f"Ingreso total Tienda 3: {ingreso_total_tienda3}")
print(f"Ingreso total Tienda 4: {ingreso_total_tienda4}")
# Out:
# Ingreso total Tienda 1: 1150880400.0
# Ingreso total Tienda 2: 1116343500.0
# Ingreso total Tienda 3: 1098019600.0
# Ingreso total Tienda 4: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
##TIENDA 1
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto').size().sort_values(ascending=False)
print("Ventas por Categoría en Tienda 1 (ordenadas de más a menos):")
print(ventas_por_categoria_tienda1)
##TIENDA 2
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto').size().sort_values(ascending=False)
print("Ventas por Categoría en Tienda 2 (ordenadas de más a menos):")
print(ventas_por_categoria_tienda2)
##TIENDA 3
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto').size().sort_values(ascending=False)
print("Ventas por Categoría en Tienda 3 (ordenadas de más a menos):")
print(ventas_por_categoria_tienda3)
##TIENDA4
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto').size().sort_values(ascending=False)
print("Ventas por Categoría en Tienda 4 (ordenadas de más a menos):")
print(ventas_por_categoria_tienda4)
# Out:
# Ventas por Categoría en Tienda 1 (ordenadas de más a menos):
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# dtype: int64
# Ventas por Categoría en Tienda 2 (ordenadas de más a menos):
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# dtype: int64
# Ventas por Categoría en Tienda 3 (ordenadas de más a menos):
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
ventas_consolidadas.plot(kind='bar', figsize=(14, 8), ax=plt.gca())
plt.title('Ventas por Categoría de Producto en Todas las Tiendas', fontsize=16)
plt.xlabel('Categoría del Producto', fontsize=12)
plt.ylabel('Número de Ventas', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Tienda', fontsize=10, title_fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

print(f"Calificación promedio Tienda 1: {calificacion_promedio_tienda1:.2f}")
print(f"Calificación promedio Tienda 2: {calificacion_promedio_tienda2:.2f}")
print(f"Calificación promedio Tienda 3: {calificacion_promedio_tienda3:.2f}")
print(f"Calificación promedio Tienda 4: {calificacion_promedio_tienda4:.2f}")
# Out:
# Calificación promedio Tienda 1: 3.98
# Calificación promedio Tienda 2: 4.04
# Calificación promedio Tienda 3: 4.05
# Calificación promedio Tienda 4: 4.00

# %%
import matplotlib.pyplot as plt
import numpy as np

calificaciones = {
    'Tienda 1': calificacion_promedio_tienda1,
    'Tienda 2': calificacion_promedio_tienda2,
    'Tienda 3': calificacion_promedio_tienda3,
    'Tienda 4': calificacion_promedio_tienda4
}

store_names = list(calificaciones.keys())
ratings = list(calificaciones.values())

plt.figure(figsize=(10, 6))
plt.barh(store_names, ratings, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])

plt.title('Calificación Promedio por Tienda (Orientación Horizontal)', fontsize=16)
plt.xlabel('Calificación Promedio', fontsize=12)
plt.ylabel('Tienda', fontsize=12)
plt.xlim(0, 5)

for i, rating in enumerate(ratings):
    plt.text(rating + 0.05, i, f'{rating:.2f}', ha='left', va='center', fontsize=10)

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
conteo_productos_tienda1 = tienda['Producto'].value_counts()

# Obtener los 5 productos más vendidos
top_5_tienda1 = conteo_productos_tienda1.head(5)

# Obtener los 5 productos menos vendidos
bottom_5_tienda1 = conteo_productos_tienda1.tail(5)

print("Top 5 Productos Más Vendidos - Tienda 1:")
print(top_5_tienda1)
print("\nTop 5 Productos Menos Vendidos - Tienda 1:")
print(bottom_5_tienda1)

##tienda 2

conteo_productos_tienda2 = tienda2['Producto'].value_counts()

# Obtener los 5 productos más vendidos
top_5_tienda2 = conteo_productos_tienda2.head(5)

# Obtener los 5 productos menos vendidos
bottom_5_tienda2 = conteo_productos_tienda2.tail(5)

print("Top 5 Productos Más Vendidos - Tienda 2:")
print(top_5_tienda2)
print("\nTop 5 Productos Menos Vendidos - Tienda 2:")
print(bottom_5_tienda2)

##tienda 3
conteo_productos_tienda3 = tienda3['Producto'].value_counts()

# Obtener los 5 productos más vendidos
top_5_tienda3 = conteo_productos_tienda3.head(5)

# Obtener los 5 productos menos vendidos
bottom_5_tienda3 = conteo_productos_tienda3.tail(5)

print("Top 5 Productos Más Vendidos - Tienda 3:")
print(top_5_tienda3)
print("\nTop 5 Productos Menos Vendidos - Tienda 3:")
print(bottom_5_tienda3)

##tienda 4
conteo_productos_tienda4 = tienda4['Producto'].value_counts()

# Obtener los 5 productos más vendidos
top_5_tienda4 = conteo_productos_tienda4.head(5)

# Obtener los 5 productos menos vendidos
bottom_5_tienda4 = conteo_productos_tienda4.tail(5)

print("Top 5 Productos Más Vendidos - Tienda 4:")
print(top_5_tienda4)
print("\nTop 5 Productos Menos Vendidos - Tienda 4:")
print(bottom_5_tienda4)
# Out:
# Top 5 Productos Más Vendidos - Tienda 1:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
#
# Top 5 Productos Menos Vendidos - Tienda 1:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# Top 5 Productos Más Vendidos - Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
#
# Top 5 Productos Menos Vendidos - Tienda 2:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
# Top 5 Productos Más Vendidos - Tienda 3:
# Producto
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio_tienda1 = tienda['Costo de envío'].mean()
envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Tienda 1: {envio_promedio_tienda1:.2f}")
print(f"Tienda 2: {envio_promedio_tienda2:.2f}")
print(f"Tienda 3: {envio_promedio_tienda3:.2f}")
print(f"Tienda 4: {envio_promedio_tienda4:.2f}")
# Out:
# Tienda 1: 26018.61
# Tienda 2: 25216.24
# Tienda 3: 24805.68
# Tienda 4: 23459.46

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingreso Total': [ingreso_total_tienda1, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4],
    'Calificación Promedio': [calificacion_promedio_tienda1, calificacion_promedio_tienda2, calificacion_promedio_tienda3, calificacion_promedio_tienda4]
}
combo_df = pd.DataFrame(data)

fig, ax1 = plt.subplots(figsize=(12, 7))

ax1.bar(combo_df['Tienda'], combo_df['Ingreso Total'], color='skyblue', label='Ingreso Total')
ax1.set_xlabel('Tienda', fontsize=12)
ax1.set_ylabel('Ingreso Total (COP)', color='skyblue', fontsize=12)
ax1.tick_params(axis='y', labelcolor='skyblue')
ax1.ticklabel_format(style='plain', axis='y')


ax2 = ax1.twinx()
ax2.plot(combo_df['Tienda'], combo_df['Calificación Promedio'], color='red', marker='o', linestyle='-', linewidth=2, label='Calificación Promedio')
ax2.set_ylabel('Calificación Promedio', color='red', fontsize=12)
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 5)


for i, rating in enumerate(combo_df['Calificación Promedio']):
    ax2.text(i, rating + 0.1, f'{rating:.2f}', color='red', ha='center', va='bottom', fontsize=10)

plt.title('Ingreso Total y Calificación Promedio por Tienda', fontsize=16)
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Informe Final

# %% [markdown]
# #**Introducción:**
# Para este análisis, me metí de lleno en los datos de ventas de Alura Store Latam. Lo que hice fue procesar más de 2,300 registros para entender realmente qué está pasando en cada una de las cuatro tiendas (Tienda 1, 2, 3 y 4).
#
# El objetivo es sencillo: ayudar al Sr. Juan a tomar una decisión estratégica. Revisé cuánto dinero entra en cada caja, qué productos son los que la gente ama y cuáles solo están juntando polvo, cuánto nos cuesta enviar los pedidos y qué tan contentos terminan los clientes. Al final, este informe no es solo una lista de números, sino una recomendación clara sobre cuál de estas tiendas es la menos eficiente y de la cual convendría deshacerse para que el negocio sea más sano.

# %% [markdown]
# #**Análisis**

# %% [markdown]
# # 1. Ingresos Totales (De más a menos):
#
# Tienda 1: $1,150,880,400.0 (La líder)
#
# Tienda 2: $1,116,343,500.0
#
# Tienda 3: $1,098,019,600.0
#
# Tienda 4: $1,038,375,700.0

# %% [markdown]
# ![grafica1.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Productos: Los 3 más vendidos vs. los 3 menos vendidos por tienda:
#
# **Tienda 1:**
#
# Top 3: Microondas (60), TV LED (60), Armario (60).
#
# Bottom 3: Celular ABXY (33), Auriculares (33), Olla de presión (35).
#
# **Tienda 2:**
#
# Top 3: Iniciando en programación (65), Microondas (62), Batería (61).
#
# Bottom 3: Juego de mesa (32), Impresora (34), Mesa de comedor (34).
#
# **Tienda 3:**
#
# Top 3: Kit de bancas (57), Mesa de comedor (56), Cama king (56).
#
# Bottom 3: Bloques de construcción (35), Microondas (36), Mochila (36).
#
# **Tienda 4:**
#
# Top 3: Cama box (62), Cubertería (59), Dashboards con Power BI (56).
#
# Bottom 3: Guitarra eléctrica (33), Armario (34), Guitarra acústica (37).

# %% [markdown]
# # 3. Calificaciones promedio (Qué tan felices están los clientes):
#
# Tienda 3: 4.05 (La mejor calificada)
#
# Tienda 2: 4.04
#
# Tienda 4: 4.00
#
# Tienda 1: 3.98 (La peor calificada)

# %% [markdown]
# ![calificacionessi.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Costo de envío promedio (menor a mayor):
#
# Tienda 4: $23,459.46
#
# Tienda 3: $24,805.68
#
# Tienda 2: $25,216.24
#
# Tienda 1: $26,018.61

# %% [markdown]
# ![calificaciones.png](data:image/png;base64,...)

# %% [markdown]
# # **Análisis de Eficiencia y Recomendación de Venta: Tienda 4**
#
# Para este análisis, procesé los datos de Alura Store Latam evaluando ingresos, rotación de inventario, satisfacción del cliente y costos logísticos. El objetivo es identificar qué sucursal es la menos eficiente para que el Sr. Juan pueda optimizar su inversión. Tras revisar los números, encontré que mientras la Tienda 1 lidera en ingresos ($1,150,880,400) y la Tienda 3 en satisfacción del cliente (4.05), el resto de las sedes presentan rendimientos variados en categorías clave como Muebles y Electrónica.

# %% [markdown]
# El veredicto es que el Sr. Juan debería vender la Tienda 4. Las razones son directas: es la que genera menos ingresos del grupo ($1,038,375,700).
#
#  Tiene el inventario de alto valor más estancado, con productos como refrigeradores y guitarras que casi no se venden. Aunque tiene los costos de envío más bajos ($23,459.46), su baja rentabilidad y falta de una fortaleza clara frente a las demás la convierten en la unidad menos eficiente. Lo más sano para el negocio es salir de ella y reinvertir ese capital en las tiendas que sí están moviendo el mercado con fuerza.
